# %%
import json
import time

# %% [markdown]
# READ THE INVENTORY DETAILS FROM THE LOCAL MACHINE

# %%
#read file into jupytor notebook
file=open('records.json','r')

txt=file.read()

file.close()

# %%
#recreate dictionary to use

recreate=json.loads(txt)

# %%
recreate
# Out:
# {'1001': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 100,
#   'updatetime': 'Sat Sep  4 09:49:18 2021',
#   'inventoryValue': 500},
#  '1002': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:49:38 2021',
#   'inventoryValue': 500},
#  '1003': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:49:55 2021',
#   'inventoryValue': 1000},
#  '1004': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:50:46 2021',
#   'inventoryValue': 100},
#  '1005': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 52,
#   'updatetime': 'Sat Sep  4 09:51:09 2021',
#   'inventoryValue': 520},
#  '1006': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 35,
#   'updatetime': 'Sat Sep  4 09:51:33 2021',
#   'inventoryValue': 700},
#  '1007': {'name': 'MilkyBar',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 28,
#   'updatetime': 'Sat Sep  4 09:52:02 2021',
#   'inventoryValue': 280},
#  '1008': {'name': 'MilkyBar',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:52:18 2021',
#   'inventoryValue': 1000},
#  '1009': {'name': 'Snickers',
#   'category': 'Chocolate',
#   'UnitPrice': 35,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:52:43 2021',
#   'inventoryValue': 1050},
#  '1010': {'name': 'Snickers',
#   'category': 'Chocolate',
#   'UnitPrice': 50,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:53:04 2021',
#   'inventoryValue': 1000},
#  '1011': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:53:33 2021',
#   'inventoryValue': 200},
#  '1012': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:53:50 2021',
#   'inventoryValue': 400},
#  '1013': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 26,
#   'updatetime': 'Sat Sep  4 09:54:11 2021',
#   'inventoryValue': 520},
#  '1014': {'name': 'GoodDay',
#   'category': 'Biscuits',
#   'UnitPrice': 10,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:54:38 2021',
#   'inventoryValue': 300},
#  '1015': {'name': 'GoodDay',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 09:54:59 2021',
#   'inventoryValue': 840},
#  '1016': {'name': 'Tiger',
#   'category': 'Biscuits',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:55:27 2021',
#   'inventoryValue': 100},
#  '1017': {'name': 'Tiger',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 43,
#   'updatetime': 'Sat Sep  4 09:55:45 2021',
#   'inventoryValue': 860},
#  '1018': {'name': 'ParleG',
#   'category': 'Biscuits',
#   'UnitPrice': 5,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:56:09 2021',
#   'inventoryValue': 250},
#  '1019': {'name': 'ParleG',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:56:31 2021',
#   'inventoryValue': 800},
#  '1020': {'name': 'MarieGold',
#   'category': 'Biscuits',
#   'UnitPrice': 10,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:56:49 2021',
#   'inventoryValue': 300},
#  '1021': {'name': 'MarieGold',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:57:06 2021',
#   'inventoryValue': 400},
#  '1022': {'name': 'Lotte-ChocoBar',
#   'category': 'ChocoCake',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:57:41 2021',
#   'inventoryValue': 400},
#  '1023': {'name': 'UncleChips',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:58:17 2021',
#   'inventoryValue': 500},
#  '1024': {'name': 'UncleChips',
#   'category': 'Chips',
#   'UnitPrice': 20,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:58:32 2021',
#   'inventoryValue': 600},
#  '1025': {'name': 'Lays(Tomato)',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:59:02 2021',
#   'inventoryValue': 150},
#  '1026': {'name': 'Lays(Tomato)',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 09:59:19 2021',
#   'inventoryValue': 420},
#  '1027': {'name': 'Lays(Indian)',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:59:46 2021',
#   'inventoryValue': 100},
#  '1028': {'name': 'Lays(Indian)',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 10:00:00 2021',
#   'inventoryValue': 420},
#  '1029': {'name': 'Crax',
#   'category': 'Rings',
#   'UnitPrice': 5,
#   'qty': 10,
#   'updatetime': 'Sat Sep  4 10:00:37 2021',
#   'inventoryValue': 50},
#  '1030': {'name': 'Crax',
#   'category': 'Rings',
#   'UnitPrice': 10,
#   'qty': 39,
#   'updatetime': 'Sat Sep  4 10:00:51 2021',
#   'inventoryValue': 390},
#  '1031': {'name': 'Bingo',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 10:01:17 2021',
#   'inventoryValue': 100},
#  '1032': {'name': 'Bingo',
#   'category': 'Chip',
#   'UnitPrice': 10,
#   'qty': 45,
#   'updatetime': 'Sat Sep  4 10:01:31 2021',
#   'inventoryValue': 450},
#  '1033': {'name': 'Bingo',
#   'category': 'Chips',
#   'UnitPrice': 20,
#   'qty': 32,
#   'updatetime': 'Sat Sep  4 10:01:46 2021',
#   'inventoryValue': 640},
#  '1034': {'name': 'Kurkure(red)',
#   'category': 'Kurkure',
#   'UnitPrice': 10,
#   'qty': 10,
#   'updatetime': 'Sat Sep  4 10:02:08 2021',
#   'inventoryValue': 100},
#  '1035': {'name': 'Kurkure(green)',
#   'category': 'Kurkure',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 10:02:28 2021',
#   'inventoryValue': 400},
#  '1036': {'name': 'Thums-Up',
#   'category': 'Soft-Drink',
#   'UnitPrice': 35,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 11:17:53 2021',
#   'inventoryValue': 1050},
#  '1037': {'name': 'Coca-Cola',
#   'category': 'Soft-Drinks',
#   'UnitPrice': 40,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 11:18:27 2021',
#   'inventoryValue': 800}}

# %% [markdown]
# DISPLAY ALL THE PRODUCTS TO THE USER/CUSTOMER

# %%
#display customer all the products
def display(record):
    for i in list(record.keys()):
        print(f"PID:{i}, PName:{record[i]['name']}, Price:{record[i]['UnitPrice']}, Quantity:{record[i]['qty']}")
display(recreate)
# Out:
# PID:1001, PName:Kit-Kat, Price:5, Quantity:90
# PID:1002, PName:Kit-Kat, Price:10, Quantity:50
# PID:1003, PName:Kit-Kat, Price:20, Quantity:50
# PID:1004, PName:DairyMilk, Price:5, Quantity:20
# PID:1005, PName:DairyMilk, Price:10, Quantity:52
# PID:1006, PName:DairyMilk, Price:20, Quantity:35
# PID:1007, PName:MilkyBar, Price:10, Quantity:28
# PID:1008, PName:MilkyBar, Price:20, Quantity:50
# PID:1009, PName:Snickers, Price:35, Quantity:30
# PID:1010, PName:Snickers, Price:50, Quantity:20
# PID:1011, PName:5-Star, Price:5, Quantity:40
# PID:1012, PName:5-Star, Price:10, Quantity:40
# PID:1013, PName:5-Star, Price:20, Quantity:26
# PID:1014, PName:GoodDay, Price:10, Quantity:30
# PID:1015, PName:GoodDay, Price:20, Quantity:42
# PID:1016, PName:Tiger, Price:5, Quantity:20
# PID:1017, PName:Tiger, Price:20, Quantity:43
# PID:1018, PName:ParleG, Price:5, Quantity:50
# PID:1019, PName:ParleG, Price:20, Quantity:40
# PID:1020, PName:MarieGold, Price:10, Quantity:30
# PID:1021, PName:MarieGold, Price:20, Quantity:20
# PID:1022, PName:Lotte-ChocoBar, Price:20, Quantity:20
# PID:1023, PName:UncleChips, Price:10, Quantity:50
# PID:1024, PName:UncleChips, Price:20, Quantity:30
# PID:1025, PName:Lays(Tomato), Price:5, Quantity:30
# PID:1026, PName:Lays(Tomato), Price:10, Quantity:42
# PID:1027, PName:Lays(Indian), Price:5, Quantity:20
# PID:1028, PName:Lays(Indian), Price:10, Quantity:42
# PID:1029, PName:Crax, Price:5, Quantity:10
# PID:1030, PName:Crax, Price:10, Quantity:39
# PID:1031, PName:Bingo, Price:5, Quantity:20
# PID:1032, PName:Bingo, Price:10, Quantity:45
# PID:1033, PName:Bingo, Price:20, Quantity:32
# PID:1034, PName:Kurkure(red), Price:10, Quantity:10
# PID:1035, PName:Kurkure(green), Price:20, Quantity:20
# PID:1036, PName:Thums-Up, Price:35, Quantity:30
# PID:1037, PName:Coca-Cola, Price:40, Quantity:20

# %%
recreate['1002']['qty']
# Out:
# 50

# %% [markdown]
# FUNCTION TO HAVE ONLY ONE ITEM OUT OF INVENTORY AT A TIME

# %%
#ask for product id from customer
#this is for one by one sale
prodId=input("enter the product id after viewing from above list: ")

if(prodId not in list(recreate.keys())):
    print("Error!,Please Enter Correct Product Id")
elif(recreate[prodId]['qty']<=0):
    print("Sorry We don't have this item is stock currently")
else:
    #ask for quantity
    quantity=int(input("How much do you need: "))
    
    if(quantity>recreate[prodId]['qty']):
        print(f"We only have {recreate[prodId]['qty']} right now. Do you want to proceed?")
        answer=input("Enter Y for yes and N for No: ")
        if(answer=="N"):
            print("Thank You for Visiting.Visit Again")
        else:
            bill=recreate[prodId]['qty']*recreate[prodId]['UnitPrice']
            print(f"Your Bill for {recreate[prodId]['qty']} at {recreate[prodId]['UnitPrice']} per piece is {bill}")
            recreate[prodId]['qty']=0

    else:
         bill=quantity*recreate[prodId]['UnitPrice']
         print(f"Your bill for {quantity} at {recreate[prodId]['UnitPrice']} per piece is {bill}")
         recreate[prodId]['qty']=recreate[prodId]['qty']-quantity
# Out:
# We only have 10 right now. Do you want to proceed?
# Thank You for Visiting.Visit Again

# %% [markdown]
# FUNCTION TO HAVE MULTIPLE ITEMS OUT OF INVENTORY IN ONE GO

# %%
#for multiple products in one go
count=int(input("How many products you want to buy: "))
prod=list(input("enter the product ids and put comma between them:").split(","))
for prodId in prod:
    if(prodId not in list(recreate.keys())):
        print(f"Error {prodId} doesn't exist!,Please Enter Correct Product Id in next go")
    elif(recreate[prodId]['qty']<=0):
        print("Sorry We don't have this item is stock currently")
    else:
        #ask for quantity
        quantity=int(input(f"How much do you need of {prodId}: "))
    
        if(quantity>recreate[prodId]['qty']):
             print(f"We only have {recreate[prodId]['qty']} right now. Do you want to proceed?")
             answer=input("Enter Y for yes and N for No: ")
             if(answer=="N"):
                  print("Thank You for Visiting.Visit Again")
             else:
                  bill=recreate[prodId]['qty']*recreate[prodId]['UnitPrice']
                  print(f"Your Bill for {recreate[prodId]['qty']} at {recreate[prodId]['UnitPrice']} per piece is {bill}")
                  recreate[prodId]['qty']=0

        else:
             bill=quantity*recreate[prodId]['UnitPrice']
             print(f"Your bill for {quantity} at {recreate[prodId]['UnitPrice']} per piece is {bill}")
             recreate[prodId]['qty']=recreate[prodId]['qty']-quantity
# Out:
# Your bill for 1 at 5 per piece is 5
# Error 1111 doesn't exist!,Please Enter Correct Product Id in next go
# Your bill for 4 at 10 per piece is 40
# Your bill for 11 at 20 per piece is 220

# %% [markdown]
# UPDATE DATA IN LOCAL MACHINE ALSO

# %%
js=json.dumps(recreate)

file=open('records.json','w')

file.write(js) #this will overwrite already existing data in json file

file.close()

# %%
#to check if the data is updated correctly
read11=open('records.json','r')

txt=read11.read()

read11.close()

# %%
txtrecord=json.loads(txt)
txtrecord
# Out:
# {'1001': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 79,
#   'updatetime': 'Sat Sep  4 09:49:18 2021',
#   'inventoryValue': 500},
#  '1002': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 34,
#   'updatetime': 'Sat Sep  4 09:49:38 2021',
#   'inventoryValue': 500},
#  '1003': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 39,
#   'updatetime': 'Sat Sep  4 09:49:55 2021',
#   'inventoryValue': 1000},
#  '1004': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 16,
#   'updatetime': 'Sat Sep  4 09:50:46 2021',
#   'inventoryValue': 100},
#  '1005': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 52,
#   'updatetime': 'Sat Sep  4 09:51:09 2021',
#   'inventoryValue': 520},
#  '1006': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 35,
#   'updatetime': 'Sat Sep  4 09:51:33 2021',
#   'inventoryValue': 700},
#  '1007': {'name': 'MilkyBar',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 28,
#   'updatetime': 'Sat Sep  4 09:52:02 2021',
#   'inventoryValue': 280},
#  '1008': {'name': 'MilkyBar',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:52:18 2021',
#   'inventoryValue': 1000},
#  '1009': {'name': 'Snickers',
#   'category': 'Chocolate',
#   'UnitPrice': 35,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:52:43 2021',
#   'inventoryValue': 1050},
#  '1010': {'name': 'Snickers',
#   'category': 'Chocolate',
#   'UnitPrice': 50,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:53:04 2021',
#   'inventoryValue': 1000},
#  '1011': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 29,
#   'updatetime': 'Sat Sep  4 09:53:33 2021',
#   'inventoryValue': 200},
#  '1012': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:53:50 2021',
#   'inventoryValue': 400},
#  '1013': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 26,
#   'updatetime': 'Sat Sep  4 09:54:11 2021',
#   'inventoryValue': 520},
#  '1014': {'name': 'GoodDay',
#   'category': 'Biscuits',
#   'UnitPrice': 10,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:54:38 2021',
#   'inventoryValue': 300},
#  '1015': {'name': 'GoodDay',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 09:54:59 2021',
#   'inventoryValue': 840},
#  '1016': {'name': 'Tiger',
#   'category': 'Biscuits',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:55:27 2021',
#   'inventoryValue': 100},
#  '1017': {'name': 'Tiger',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 43,
#   'updatetime': 'Sat Sep  4 09:55:45 2021',
#   'inventoryValue': 860},
#  '1018': {'name': 'ParleG',
#   'category': 'Biscuits',
#   'UnitPrice': 5,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:56:09 2021',
#   'inventoryValue': 250},
#  '1019': {'name': 'ParleG',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:56:31 2021',
#   'inventoryValue': 800},
#  '1020': {'name': 'MarieGold',
#   'category': 'Biscuits',
#   'UnitPrice': 10,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:56:49 2021',
#   'inventoryValue': 300},
#  '1021': {'name': 'MarieGold',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:57:06 2021',
#   'inventoryValue': 400},
#  '1022': {'name': 'Lotte-ChocoBar',
#   'category': 'ChocoCake',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:57:41 2021',
#   'inventoryValue': 400},
#  '1023': {'name': 'UncleChips',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:58:17 2021',
#   'inventoryValue': 500},
#  '1024': {'name': 'UncleChips',
#   'category': 'Chips',
#   'UnitPrice': 20,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:58:32 2021',
#   'inventoryValue': 600},
#  '1025': {'name': 'Lays(Tomato)',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:59:02 2021',
#   'inventoryValue': 150},
#  '1026': {'name': 'Lays(Tomato)',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 09:59:19 2021',
#   'inventoryValue': 420},
#  '1027': {'name': 'Lays(Indian)',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:59:46 2021',
#   'inventoryValue': 100},
#  '1028': {'name': 'Lays(Indian)',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 10:00:00 2021',
#   'inventoryValue': 420},
#  '1029': {'name': 'Crax',
#   'category': 'Rings',
#   'UnitPrice': 5,
#   'qty': 10,
#   'updatetime': 'Sat Sep  4 10:00:37 2021',
#   'inventoryValue': 50},
#  '1030': {'name': 'Crax',
#   'category': 'Rings',
#   'UnitPrice': 10,
#   'qty': 34,
#   'updatetime': 'Sat Sep  4 10:00:51 2021',
#   'inventoryValue': 390},
#  '1031': {'name': 'Bingo',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 10:01:17 2021',
#   'inventoryValue': 100},
#  '1032': {'name': 'Bingo',
#   'category': 'Chip',
#   'UnitPrice': 10,
#   'qty': 45,
#   'updatetime': 'Sat Sep  4 10:01:31 2021',
#   'inventoryValue': 450},
#  '1033': {'name': 'Bingo',
#   'category': 'Chips',
#   'UnitPrice': 20,
#   'qty': 32,
#   'updatetime': 'Sat Sep  4 10:01:46 2021',
#   'inventoryValue': 640},
#  '1034': {'name': 'Kurkure(red)',
#   'category': 'Kurkure',
#   'UnitPrice': 10,
#   'qty': 10,
#   'updatetime': 'Sat Sep  4 10:02:08 2021',
#   'inventoryValue': 100},
#  '1035': {'name': 'Kurkure(green)',
#   'category': 'Kurkure',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 10:02:28 2021',
#   'inventoryValue': 400},
#  '1036': {'name': 'Thums-Up',
#   'category': 'Soft-Drink',
#   'UnitPrice': 35,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 11:17:53 2021',
#   'inventoryValue': 1050},
#  '1037': {'name': 'Coca-Cola',
#   'category': 'Soft-Drinks',
#   'UnitPrice': 40,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 11:18:27 2021',
#   'inventoryValue': 800}}
