# %%
import json
import time

# %% [markdown]
# #READ FILE FROM LOCAL MACHINE

# %%
#read file from local
file = open("records.json",'r')

txt=file.read()

file.close()

# %% [markdown]
# #CREATE DICTIONARY FROM TXT FILE

# %%
recreate=json.loads(txt)
# Out:
# {'1001': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 79,
#   'updatetime': 'Sat Sep  4 09:49:18 2021',
#   'inventoryValue': 500},
#  '1002': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 34,
#   'updatetime': 'Sat Sep  4 09:49:38 2021',
#   'inventoryValue': 500},
#  '1003': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 39,
#   'updatetime': 'Sat Sep  4 09:49:55 2021',
#   'inventoryValue': 1000},
#  '1004': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 16,
#   'updatetime': 'Sat Sep  4 09:50:46 2021',
#   'inventoryValue': 100},
#  '1005': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 52,
#   'updatetime': 'Sat Sep  4 09:51:09 2021',
#   'inventoryValue': 520},
#  '1006': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 35,
#   'updatetime': 'Sat Sep  4 09:51:33 2021',
#   'inventoryValue': 700},
#  '1007': {'name': 'MilkyBar',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 28,
#   'updatetime': 'Sat Sep  4 09:52:02 2021',
#   'inventoryValue': 280},
#  '1008': {'name': 'MilkyBar',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:52:18 2021',
#   'inventoryValue': 1000},
#  '1009': {'name': 'Snickers',
#   'category': 'Chocolate',
#   'UnitPrice': 35,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:52:43 2021',
#   'inventoryValue': 1050},
#  '1010': {'name': 'Snickers',
#   'category': 'Chocolate',
#   'UnitPrice': 50,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:53:04 2021',
#   'inventoryValue': 1000},
#  '1011': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 29,
#   'updatetime': 'Sat Sep  4 09:53:33 2021',
#   'inventoryValue': 200},
#  '1012': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:53:50 2021',
#   'inventoryValue': 400},
#  '1013': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 26,
#   'updatetime': 'Sat Sep  4 09:54:11 2021',
#   'inventoryValue': 520},
#  '1014': {'name': 'GoodDay',
#   'category': 'Biscuits',
#   'UnitPrice': 10,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:54:38 2021',
#   'inventoryValue': 300},
#  '1015': {'name': 'GoodDay',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 09:54:59 2021',
#   'inventoryValue': 840},
#  '1016': {'name': 'Tiger',
#   'category': 'Biscuits',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:55:27 2021',
#   'inventoryValue': 100},
#  '1017': {'name': 'Tiger',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 43,
#   'updatetime': 'Sat Sep  4 09:55:45 2021',
#   'inventoryValue': 860},
#  '1018': {'name': 'ParleG',
#   'category': 'Biscuits',
#   'UnitPrice': 5,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:56:09 2021',
#   'inventoryValue': 250},
#  '1019': {'name': 'ParleG',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:56:31 2021',
#   'inventoryValue': 800},
#  '1020': {'name': 'MarieGold',
#   'category': 'Biscuits',
#   'UnitPrice': 10,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:56:49 2021',
#   'inventoryValue': 300},
#  '1021': {'name': 'MarieGold',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:57:06 2021',
#   'inventoryValue': 400},
#  '1022': {'name': 'Lotte-ChocoBar',
#   'category': 'ChocoCake',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:57:41 2021',
#   'inventoryValue': 400},
#  '1023': {'name': 'UncleChips',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:58:17 2021',
#   'inventoryValue': 500},
#  '1024': {'name': 'UncleChips',
#   'category': 'Chips',
#   'UnitPrice': 20,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:58:32 2021',
#   'inventoryValue': 600},
#  '1025': {'name': 'Lays(Tomato)',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:59:02 2021',
#   'inventoryValue': 150},
#  '1026': {'name': 'Lays(Tomato)',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 09:59:19 2021',
#   'inventoryValue': 420},
#  '1027': {'name': 'Lays(Indian)',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:59:46 2021',
#   'inventoryValue': 100},
#  '1028': {'name': 'Lays(Indian)',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 10:00:00 2021',
#   'inventoryValue': 420},
#  '1029': {'name': 'Crax',
#   'category': 'Rings',
#   'UnitPrice': 5,
#   'qty': 10,
#   'updatetime': 'Sat Sep  4 10:00:37 2021',
#   'inventoryValue': 50},
#  '1030': {'name': 'Crax',
#   'category': 'Rings',
#   'UnitPrice': 10,
#   'qty': 34,
#   'updatetime': 'Sat Sep  4 10:00:51 2021',
#   'inventoryValue': 390},
#  '1031': {'name': 'Bingo',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 10:01:17 2021',
#   'inventoryValue': 100},
#  '1032': {'name': 'Bingo',
#   'category': 'Chip',
#   'UnitPrice': 10,
#   'qty': 45,
#   'updatetime': 'Sat Sep  4 10:01:31 2021',
#   'inventoryValue': 450},
#  '1033': {'name': 'Bingo',
#   'category': 'Chips',
#   'UnitPrice': 20,
#   'qty': 32,
#   'updatetime': 'Sat Sep  4 10:01:46 2021',
#   'inventoryValue': 640},
#  '1034': {'name': 'Kurkure(red)',
#   'category': 'Kurkure',
#   'UnitPrice': 10,
#   'qty': 10,
#   'updatetime': 'Sat Sep  4 10:02:08 2021',
#   'inventoryValue': 100},
#  '1035': {'name': 'Kurkure(green)',
#   'category': 'Kurkure',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 10:02:28 2021',
#   'inventoryValue': 400},
#  '1036': {'name': 'Thums-Up',
#   'category': 'Soft-Drink',
#   'UnitPrice': 35,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 11:17:53 2021',
#   'inventoryValue': 1050},
#  '1037': {'name': 'Coca-Cola',
#   'category': 'Soft-Drinks',
#   'UnitPrice': 40,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 11:18:27 2021',
#   'inventoryValue': 800}}

# %% [markdown]
# #DISPLAY FUNCTION TO SHOW DETAILS TO CUSTOMER

# %%
def display(record):
    for i in list(record.keys()):
        print(f"PID:{i}, PName:{record[i]['name']}, Price:{record[i]['UnitPrice']}, Quantity:{record[i]['qty']}")

# %%
display(recreate)
# Out:
# PID:1001, PName:Kit-Kat, Price:5, Quantity:79
# PID:1002, PName:Kit-Kat, Price:10, Quantity:34
# PID:1003, PName:Kit-Kat, Price:20, Quantity:39
# PID:1004, PName:DairyMilk, Price:5, Quantity:16
# PID:1005, PName:DairyMilk, Price:10, Quantity:52
# PID:1006, PName:DairyMilk, Price:20, Quantity:35
# PID:1007, PName:MilkyBar, Price:10, Quantity:28
# PID:1008, PName:MilkyBar, Price:20, Quantity:50
# PID:1009, PName:Snickers, Price:35, Quantity:30
# PID:1010, PName:Snickers, Price:50, Quantity:20
# PID:1011, PName:5-Star, Price:5, Quantity:29
# PID:1012, PName:5-Star, Price:10, Quantity:40
# PID:1013, PName:5-Star, Price:20, Quantity:26
# PID:1014, PName:GoodDay, Price:10, Quantity:30
# PID:1015, PName:GoodDay, Price:20, Quantity:42
# PID:1016, PName:Tiger, Price:5, Quantity:20
# PID:1017, PName:Tiger, Price:20, Quantity:43
# PID:1018, PName:ParleG, Price:5, Quantity:50
# PID:1019, PName:ParleG, Price:20, Quantity:40
# PID:1020, PName:MarieGold, Price:10, Quantity:30
# PID:1021, PName:MarieGold, Price:20, Quantity:20
# PID:1022, PName:Lotte-ChocoBar, Price:20, Quantity:20
# PID:1023, PName:UncleChips, Price:10, Quantity:50
# PID:1024, PName:UncleChips, Price:20, Quantity:30
# PID:1025, PName:Lays(Tomato), Price:5, Quantity:30
# PID:1026, PName:Lays(Tomato), Price:10, Quantity:42
# PID:1027, PName:Lays(Indian), Price:5, Quantity:20
# PID:1028, PName:Lays(Indian), Price:10, Quantity:42
# PID:1029, PName:Crax, Price:5, Quantity:10
# PID:1030, PName:Crax, Price:10, Quantity:34
# PID:1031, PName:Bingo, Price:5, Quantity:20
# PID:1032, PName:Bingo, Price:10, Quantity:45
# PID:1033, PName:Bingo, Price:20, Quantity:32
# PID:1034, PName:Kurkure(red), Price:10, Quantity:10
# PID:1035, PName:Kurkure(green), Price:20, Quantity:20
# PID:1036, PName:Thums-Up, Price:35, Quantity:30
# PID:1037, PName:Coca-Cola, Price:40, Quantity:20

# %% [markdown]
# #SALES RECORD FOR GETTING ALL THE SALES AT THE END OF THE DAY

# %%
#sales dictionary for having all the records of the purchase
salesrecords={}

# %%
def salesrecord(prodId,quantity,bill):
    
    if prodId not in list(salesrecords.keys()):
        salesrecords[prodId]={'quantitySold':quantity,'TotalBill':bill}
    else:
        salesrecords[prodId]['quantitySold']+=quantity
        salesrecords[prodId]['TotalBill']+=bill

# %% [markdown]
# #PURCHASE FUNCTION PERFORM PURCHASE OF ITEMS FROM THE INVENTORY

# %%
def purchaseAndSales(recreate):
    count=int(input("How many products you want to buy: "))
    prod=list(input("enter the product ids and put comma between them:").split(","))
    
    for prodId in prod:
         if(prodId not in list(recreate.keys())):
                 print(f"Error {prodId} doesn't exist!,Please Enter Correct Product Id in next go")
         #if quantity in store is zero        
         elif(recreate[prodId]['qty']<=0):
                 print("Sorry We don't have this item is stock currently")
         else:
               #ask for quantity
               quantity=int(input(f"How much do you need of {prodId}: "))
    
               if(quantity>recreate[prodId]['qty']):
                       print(f"We only have {recreate[prodId]['qty']} right now. Do you want to proceed?")
                       answer=input("Enter Y for yes and N for No: ")
                       if(answer=="N"):
                            print("Thank You for Visiting.Visit Again")
                       else:
                            bill=recreate[prodId]['qty']*recreate[prodId]['UnitPrice']
                            print(f"Your Bill for {recreate[prodId]['qty']} at {recreate[prodId]['UnitPrice']} per piece is {bill}")
                            recreate[prodId]['qty']=0
                            recreate[prodId]['updatetime']=time.ctime()
                            recreate[prodId]['inventoryValue']=recreate[prodId]['qty']*recreate[prodId]['UnitPrice']
                            salesrecord(prodId,quantity,bill)

               else:
                       bill=quantity*recreate[prodId]['UnitPrice']
                       print(f"Your bill for {quantity} at {recreate[prodId]['UnitPrice']} per piece is {bill}")
                       recreate[prodId]['qty']=recreate[prodId]['qty']-quantity
                       recreate[prodId]['updatetime']=time.ctime()
                       recreate[prodId]['inventoryValue']=recreate[prodId]['qty']*recreate[prodId]['UnitPrice']
                       salesrecord(prodId,quantity,bill)
    return salesrecords

# %%
sales=purchaseAndSales(recreate)
# Out:
# Your bill for 12 at 5 per piece is 60
# Your bill for 11 at 10 per piece is 110

# %%
sales
# Out:
# {'1001': {'quantitySold': 12, 'TotalBill': 60},
#  '1002': {'quantitySold': 11, 'TotalBill': 110}}

# %% [markdown]
# #FUNCTION TO CALCULATE THE TOTAL SALE AT THE END OF THE DAY

# %%
#now to calculate full sale of the day
def TotalSale(sales):
    totalsale=0
    for i in list(sales.keys()):
          totalsale+=sales[i]['TotalBill']
    
    print(f"total sale of day is: INR {totalsale}")

# %% [markdown]
# #FUNCTION TO CHECK MAX SOLD PRODUCT

# %%
def MaxSale():
    maxSale=0
    
    maxSaleid=0
    
    file=open('salesRecord.json','r')

    text=file.read()

    file.close()

    saleRecreate=json.loads(text)


    for i in list(saleRecreate.keys()):
             if(saleRecreate[i]['TotalBill']>maxSale):
                        maxSale=saleRecreate[i]['TotalBill']
                        maxSaleid=i
    print(f"MAX SOLD PRODUCT IS: {maxSaleid} \nTotal Quantity Sold is: {saleRecreate[maxSaleid]['quantitySold']}\nTotal Sale in INR is: {maxSale}")

# %%
MaxSale()
# Out:
# MAX SOLD PRODUCT IS: 1002
# Total Quantity Sold is: 11
# Total Sale in INR is: 110

# %% [markdown]
# #UPDATING ALL THE DATA IN LOCAL MACHINE

# %%
#update the details into final local file

js =json.dumps(recreate)

dumping=open('records.json','w')

dumping.write(js)

dumping.close()

# %% [markdown]
# #READING DATA FROM LOCAL FOR CONFIRMATION OF DATA UPDATION SUCCESSFULLY

# %%
#read to confirm if done successfully

fileread=open('records.json','r')

txtnew=fileread.read()

fileread.close()

check=json.loads(txtnew)

# %%
check
# Out:
# {'1001': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 67,
#   'updatetime': 'Sat Sep  4 12:59:21 2021',
#   'inventoryValue': 335},
#  '1002': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 23,
#   'updatetime': 'Sat Sep  4 12:59:24 2021',
#   'inventoryValue': 230},
#  '1003': {'name': 'Kit-Kat',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 39,
#   'updatetime': 'Sat Sep  4 09:49:55 2021',
#   'inventoryValue': 1000},
#  '1004': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 16,
#   'updatetime': 'Sat Sep  4 09:50:46 2021',
#   'inventoryValue': 100},
#  '1005': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 52,
#   'updatetime': 'Sat Sep  4 09:51:09 2021',
#   'inventoryValue': 520},
#  '1006': {'name': 'DairyMilk',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 35,
#   'updatetime': 'Sat Sep  4 09:51:33 2021',
#   'inventoryValue': 700},
#  '1007': {'name': 'MilkyBar',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 28,
#   'updatetime': 'Sat Sep  4 09:52:02 2021',
#   'inventoryValue': 280},
#  '1008': {'name': 'MilkyBar',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:52:18 2021',
#   'inventoryValue': 1000},
#  '1009': {'name': 'Snickers',
#   'category': 'Chocolate',
#   'UnitPrice': 35,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:52:43 2021',
#   'inventoryValue': 1050},
#  '1010': {'name': 'Snickers',
#   'category': 'Chocolate',
#   'UnitPrice': 50,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:53:04 2021',
#   'inventoryValue': 1000},
#  '1011': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 5,
#   'qty': 29,
#   'updatetime': 'Sat Sep  4 09:53:33 2021',
#   'inventoryValue': 200},
#  '1012': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 10,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:53:50 2021',
#   'inventoryValue': 400},
#  '1013': {'name': '5-Star',
#   'category': 'Chocolate',
#   'UnitPrice': 20,
#   'qty': 26,
#   'updatetime': 'Sat Sep  4 09:54:11 2021',
#   'inventoryValue': 520},
#  '1014': {'name': 'GoodDay',
#   'category': 'Biscuits',
#   'UnitPrice': 10,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:54:38 2021',
#   'inventoryValue': 300},
#  '1015': {'name': 'GoodDay',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 09:54:59 2021',
#   'inventoryValue': 840},
#  '1016': {'name': 'Tiger',
#   'category': 'Biscuits',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:55:27 2021',
#   'inventoryValue': 100},
#  '1017': {'name': 'Tiger',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 43,
#   'updatetime': 'Sat Sep  4 09:55:45 2021',
#   'inventoryValue': 860},
#  '1018': {'name': 'ParleG',
#   'category': 'Biscuits',
#   'UnitPrice': 5,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:56:09 2021',
#   'inventoryValue': 250},
#  '1019': {'name': 'ParleG',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 40,
#   'updatetime': 'Sat Sep  4 09:56:31 2021',
#   'inventoryValue': 800},
#  '1020': {'name': 'MarieGold',
#   'category': 'Biscuits',
#   'UnitPrice': 10,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:56:49 2021',
#   'inventoryValue': 300},
#  '1021': {'name': 'MarieGold',
#   'category': 'Biscuits',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:57:06 2021',
#   'inventoryValue': 400},
#  '1022': {'name': 'Lotte-ChocoBar',
#   'category': 'ChocoCake',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:57:41 2021',
#   'inventoryValue': 400},
#  '1023': {'name': 'UncleChips',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 50,
#   'updatetime': 'Sat Sep  4 09:58:17 2021',
#   'inventoryValue': 500},
#  '1024': {'name': 'UncleChips',
#   'category': 'Chips',
#   'UnitPrice': 20,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:58:32 2021',
#   'inventoryValue': 600},
#  '1025': {'name': 'Lays(Tomato)',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 09:59:02 2021',
#   'inventoryValue': 150},
#  '1026': {'name': 'Lays(Tomato)',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 09:59:19 2021',
#   'inventoryValue': 420},
#  '1027': {'name': 'Lays(Indian)',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 09:59:46 2021',
#   'inventoryValue': 100},
#  '1028': {'name': 'Lays(Indian)',
#   'category': 'Chips',
#   'UnitPrice': 10,
#   'qty': 42,
#   'updatetime': 'Sat Sep  4 10:00:00 2021',
#   'inventoryValue': 420},
#  '1029': {'name': 'Crax',
#   'category': 'Rings',
#   'UnitPrice': 5,
#   'qty': 10,
#   'updatetime': 'Sat Sep  4 10:00:37 2021',
#   'inventoryValue': 50},
#  '1030': {'name': 'Crax',
#   'category': 'Rings',
#   'UnitPrice': 10,
#   'qty': 34,
#   'updatetime': 'Sat Sep  4 10:00:51 2021',
#   'inventoryValue': 390},
#  '1031': {'name': 'Bingo',
#   'category': 'Chips',
#   'UnitPrice': 5,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 10:01:17 2021',
#   'inventoryValue': 100},
#  '1032': {'name': 'Bingo',
#   'category': 'Chip',
#   'UnitPrice': 10,
#   'qty': 45,
#   'updatetime': 'Sat Sep  4 10:01:31 2021',
#   'inventoryValue': 450},
#  '1033': {'name': 'Bingo',
#   'category': 'Chips',
#   'UnitPrice': 20,
#   'qty': 32,
#   'updatetime': 'Sat Sep  4 10:01:46 2021',
#   'inventoryValue': 640},
#  '1034': {'name': 'Kurkure(red)',
#   'category': 'Kurkure',
#   'UnitPrice': 10,
#   'qty': 10,
#   'updatetime': 'Sat Sep  4 10:02:08 2021',
#   'inventoryValue': 100},
#  '1035': {'name': 'Kurkure(green)',
#   'category': 'Kurkure',
#   'UnitPrice': 20,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 10:02:28 2021',
#   'inventoryValue': 400},
#  '1036': {'name': 'Thums-Up',
#   'category': 'Soft-Drink',
#   'UnitPrice': 35,
#   'qty': 30,
#   'updatetime': 'Sat Sep  4 11:17:53 2021',
#   'inventoryValue': 1050},
#  '1037': {'name': 'Coca-Cola',
#   'category': 'Soft-Drinks',
#   'UnitPrice': 40,
#   'qty': 20,
#   'updatetime': 'Sat Sep  4 11:18:27 2021',
#   'inventoryValue': 800}}

# %% [markdown]
# #ADDING DATE TO EACH DATA FOR IDENTIFYING THE FUCNTIONS

# %%
for i in list(sales.keys()):
    
    sales[i]['date']=time.ctime()
# Out:
# {'1001': {'quantitySold': 12,
#   'TotalBill': 60,
#   'date': 'Sat Sep  4 13:16:17 2021'},
#  '1002': {'quantitySold': 11,
#   'TotalBill': 110,
#   'date': 'Sat Sep  4 13:16:17 2021'}}

# %% [markdown]
# #Creating json file of the sales data

# %%
jsale=json.dumps(sales)

convert=open('salesRecord.json','w')

convert.write(jsale)

convert.close()
